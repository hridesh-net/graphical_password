# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Get the file name of the image from the user
file_name = input("Enter the file name of the image: ")

# Read the image using the Image class from the PIL library
img = Image.open(file_name)

# Convert the image to a Numpy array
img_array = np.array(img)

# Divide the image into segments of size 50x50
segment_size = 750
segments = [img_array[i:i + segment_size, j:j + segment_size] for i in range(0, img_array.shape[0], segment_size) for j in range(0, img_array.shape[1], segment_size)]

# Show the segments using Matplotlib
for i, segment in enumerate(segments):
    plt.figure()
    plt.imshow(segment)
    plt.title("Segment {}".format(i + 1))
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8016\1073219317.py:20: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
